# %%
calculate_alpha <- function(p) {
    (1 + p) / (1 - p)
}

# %%
calculate_p <- function(alpha) {
    (alpha - 1) / (alpha + 1)
}

# %%
calculate_p(1.5)
calculate_p(2.2)
# Out:
# [1] 0.2
# [1] 0.375

# %%
p  <- seq(0.01, 0.9, 0.01)
plot(p, calculate_alpha(p))
abline(h = 1.5)
abline(h = 2.2)
# Out:
# plot without title
