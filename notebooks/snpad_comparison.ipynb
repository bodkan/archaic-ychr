# %%
library(tidyverse)
library(here)

suppressPackageStartupMessages(library(VariantAnnotation))

devtools::load_all(".")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# here() starts at /mnt/expressions/mp/archaic-ychr
# Loading ychr

# %% [markdown]
# ### Read Mez2 genotypes generated by `bam-sample`

# %%
bamsample <- read_vcf(here("data/vcf/full_mez2.vcf.gz"), mindp = 3, maxdp = 0.98)

# %% [markdown]
# ### Read Mez2 genotypes generated by snpAD

# %%
path <- here("data/vcf/full_mez2_snpad.vcf.gz")

vcf <- VariantAnnotation::readVcf(path)
gr <- GenomicRanges::granges(vcf)
dp <- VariantAnnotation::geno(vcf)$DP

# %%
mask <- apply(dp, 2, function(i) ifelse(i >= 3 & i <= quantile(i, 0.98, na.rm = TRUE), TRUE, FALSE))
if ("chimp" %in% colnames(mask)) 
    mask[, "chimp"] <- TRUE

# %%
gt <- VariantAnnotation::geno(vcf)$GT %>% replace(. == ".", NA) %>% replace(!mask, NA)

# %%
length(as.character(GenomicRanges::seqnames(gr)))
# Out:
# [1] 6806675

# %%
length(GenomicRanges::start(gr))
# Out:
# [1] 6806675

# %%
length(as.character(gr$REF))
# Out:
# [1] 6806675

# %%
length(as.character(unlist(gr$ALT)))
# Out:
# [1] 6806677

# %%
elementNROWS(gr$ALT)  %>% table
# Out:
# .
#       1       2
# 6806673       2

# %%
biallelic_pos <- elementNROWS(gr$ALT) < 2

gt_df <- tibble::as_tibble(gt)[biallelic_pos, ]

info_df <- tibble::tibble(
    chrom = as.character(GenomicRanges::seqnames(gr))[biallelic_pos], 
    pos = GenomicRanges::start(gr)[biallelic_pos],
    REF = as.character(gr$REF)[biallelic_pos], 
    ALT = as.character(unlist(gr$ALT[biallelic_pos, ]))
)

df <- dplyr::bind_cols(info_df, gt_df)
colnames(df) <- str_replace_all(colnames(df), "-", "_")

# %%
snpad <- df

# %% [markdown]
# ### Read pileups

# %%
pileups <- read_tsv(here("data/pileup/full_mez2.txt.gz"), col_types = "cicccccc") %>% rename(REF = ref)

# %%
head(pileups)
# Out:
#   chrom pos     REF pileup A C G T
# 1 Y     2649811 A   A      1 0 0 0
# 2 Y     2649812 A   AA     2 0 0 0
# 3 Y     2649813 A   AAA    3 0 0 0
# 4 Y     2649814 A   AAAA   4 0 0 0
# 5 Y     2649815 A   AAAA   4 0 0 0
# 6 Y     2649816 A   AAAA   4 0 0 0

# %% [markdown]
# ### Merge all three tables into one

# %%
merged <-
    full_join(bamsample, snpad, by = c("chrom", "pos", "REF")) %>%
    left_join(pileups, by = c("chrom", "pos", "REF"))

# %%
nrow(merged)
# Out:
# [1] 7374200

# %%
head(merged)
# Out:
#   chrom pos     REF ALT.x mez2 ALT.y mez2_snpad pileup A C G T
# 1 Y     2649811 A         NA   NA    NA         A      1 0 0 0
# 2 Y     2649812 A         NA   NA    NA         AA     2 0 0 0
# 3 Y     2649813 A          0   NA    NA         AAA    3 0 0 0
# 4 Y     2649814 A          0   NA    NA         AAAA   4 0 0 0
# 5 Y     2649815 A          0   NA    NA         AAAA   4 0 0 0
# 6 Y     2649816 A          0   NA    NA         AAAA   4 0 0 0

# %% [markdown]
# There is one site which is called as heterozygous by snpAD but has exceedingly high coverage and is filtered out:

# %%
filter(merged, ALT.x != ALT.y)
# Out:
#   chrom pos      REF ALT.x mez2 ALT.y mez2_snpad
# 1 Y     13449837 T         NA   A     NA
#   pileup                                                    A C G T
# 1 TTTTTTATTTTTTATTTTTTTTTTTATATTTATTTTTTTTTTTTTTTTTTTTTTTTT 5 0 0 52

# %%
merged <- mutate(merged, ALT = ALT.y) %>% select(-ALT.x, -ALT.y) %>%
    mutate(total = as.numeric(A) + as.numeric(C) + as.numeric(G) + as.numeric(T))

# %% [markdown]
# # Miscalled ALTs?

# %%
filter(merged, mez2 == "1" & mez2_snpad != "1/1") %>% head
# Out:
#      chrom pos REF mez2 mez2_snpad pileup A C G T ALT total

# %% [markdown]
# None.

# %% [markdown]
# # Miscalled REFs?

# %%
filter(merged, mez2 == "0" & mez2_snpad != "0/0") %>% head
# Out:
#      chrom pos REF mez2 mez2_snpad pileup A C G T ALT total

# %% [markdown]
# None.

# %% [markdown]
# # Investigate snpAD hets
#
# These must be errors, because we're dealing with the Y chromosome.

# %% [markdown]
# How many?

# %%
filter(merged, mez2_snpad != "0/0", mez2_snpad != "1/1") %>% nrow
# Out:
# [1] 440

# %% [markdown]
# Do I even call something at snpAD het sites?

# %%
filter(merged, mez2_snpad == "0/1") %>% filter(!is.na(mez2))
# Out:
#      chrom pos REF mez2 mez2_snpad pileup A C G T ALT total

# %% [markdown]
# Nope, all snpAD het sites are excluded with my genotyper.

# %% [markdown]
# Write out all snpAD het sites:

# %%
filter(merged, mez2_snpad == "0/1")
# Out:
#     chrom pos      REF mez2 mez2_snpad pileup                         A  C  G
# 1   Y     2702987  G   NA   0/1        TGTGATGG                       1  0  4
# 2   Y     2702988  T   NA   0/1        TTGTTTTTG                      0  0  2
# 3   Y     2777844  G   NA   0/1        GGGGAGAGAGAGAGAG               6  0  10
# 4   Y     2841055  G   NA   0/1        GGGGGGGGAAAAAAAGGG             7  0  11
# 5   Y     2854738  G   NA   0/1        GAGGGAAGGGGGAAA                6  0  9
# 6   Y     3405761  T   NA   0/1        TTTTTTTACATTTTAT               3  1  0
# 7   Y     3405762  A   NA   0/1        AAAAAAATATAAAATAA              14 0  0
# 8   Y     3405811  A   NA   0/1        AACAAACAAAAACCACAA             13 5  0
# 9   Y     3406061  G   NA   0/1        GGAAGAAGGGGGGGGAGG             5  0  13
# 10  Y     3406216  G   NA   0/1        GAGAAAGGGGAGGGGGGGGGAAGA       8  0  16
# 11  Y     3406277  C   NA   0/1        CCTTCCCCCCCCCCTTCTCCCTCCTCCTCC 0  22 0
# 12  Y     3406292  T   NA   0/1        CTTTTTCTTTTTTTTTCTTCTTCTTT     0  5  0
# 13  Y     3406349  A   NA   0/1        AAAACCCCAAAAAAACCAA            13 6  0
# 14  Y     3406365  G   NA   0/1        GGGAAAGGGGGGAAGGGAGG           6  0  14
# 15  Y     3406710  C   NA   0/1        CCCCCAACCCCCCACCCCA            4  15 0
# 16  Y     3406853  T   NA   0/1        TTTTTTTTTCTCTTCTCCTTCTCT       0  7  0
# 17  Y     3407112  A   NA   0/1        AGAGGA                         3  0  3
# 18  Y     3407527  T   NA   0/1        CCTTCT                         0  3  0
# 436 Y     24400686 T   NA   0/1        TTTCCTTCCCTCCC                 0  8  0
# 437 Y     24499652 C   NA   0/1        CCCCCCCACGGACTGAAC             4  10 3
# 438 Y     24499654 G   NA   0/1        GGGGGGGCGGGCGGGCTGGAC          1  4  15
# 439 Y     28759638 A   NA   0/1        CCACAAACACAAA                  8  5  0
# 440 Y     28759669 T   NA   0/1        GGTTTGTTTTTTTGTGTGGTTTTTTTT    0  0  7
#     T  ALT total
# 1   3  T    8
# 2   7  G    9
# 3   0  A   16
# 4   0  A   18
# 5   0  A   15
# 6   12 A   16
# 7   3  T   17
# 8   0  C   18
# 9   0  A   18
# 10  0  A   24
# 11  8  T   30
# 12  21 C   26
# 13  0  C   19
# 14  0  A   20
# 15  0  A   19
# 16  17 C   24
# 17  0  G    6
# 18  3  C    6
# 19  0  G   16
# 20  0  C   19
# 21  0  G   14
# 22  14 C   19
# 23  1  A   20
# 24  19 A   25
# 25  5  T   20
# 26  0  C   19
# 27  0  G   27
# 28  9  C   12
# 29  0  A   21
# 30  1  G   15
# ⋮   ⋮  ⋮   ⋮
# 411 NA A   NA
# 412 8  T   18
# 413 1  C   10
# 414 0  A   19
# 415 6  C    9
# 416 4  T   20
# 417 NA C   NA
# 418 7  T   10
# 419 5  T   15
# 420 11 A   14
# 421 0  A   20
# 422 0  C   21
# 423 8  T   19
# 424 NA A   NA
# 425 2  A    4
# 426 2  G    4
# 427 NA C   NA
# 428 17 G   21
# 429 4  A    6
# 430 3  T   12
# 431 24 C   28
# 432 19 G   24
# 433 0  C   22
# 434 0  A    5
# 435 7  C   17
# 436 6  C   14
# 437 1  A   18
# 438 1  C   21
# 439 0  C   13
# 440 20 G   27

# %% [markdown]
# Mixture of bases at sites that I ignore but snpAD calls? Note that these carry mixtures of alleles which I remove, but snpAD calls as homozygous.

# %%
filter(merged, is.na(mez2) & !is.na(mez2_snpad) & !is.na(A)) %>% arrange(desc(A), desc(C), desc(G), desc(T)) %>% filter(total < 4)
# Out:
#      chrom pos      REF mez2 mez2_snpad pileup A C G T ALT total
# 1    Y      2652955 A   NA   0/0        AAC    2 1 0 0     3
# 2    Y      6900142 A   NA   0/0        CAA    2 1 0 0     3
# 3    Y      6900147 A   NA   0/0        CAA    2 1 0 0     3
# 4    Y      6936384 A   NA   0/0        AAC    2 1 0 0     3
# 5    Y      7637931 A   NA   0/0        CAA    2 1 0 0     3
# 6    Y      7948643 A   NA   0/0        ACA    2 1 0 0     3
# 7    Y      8014399 A   NA   0/0        AAC    2 1 0 0     3
# 8    Y      8037425 A   NA   0/0        AAC    2 1 0 0     3
# 9    Y      8160183 A   NA   0/0        AAC    2 1 0 0     3
# 10   Y      8224198 A   NA   0/0        CAA    2 1 0 0     3
# 11   Y      8668392 A   NA   0/0        ACA    2 1 0 0     3
# 12   Y      9139402 A   NA   0/0        CAA    2 1 0 0     3
# 13   Y     10033113 A   NA   0/0        AAC    2 1 0 0     3
# 14   Y     14468991 A   NA   0/0        ACA    2 1 0 0     3
# 15   Y     14741927 A   NA   0/0        CAA    2 1 0 0     3
# 16   Y     14789704 A   NA   0/0        AAC    2 1 0 0     3
# 17   Y     14852078 A   NA   0/0        ACA    2 1 0 0     3
# 18   Y     15641988 A   NA   0/0        AAC    2 1 0 0     3
# 19   Y     16184606 A   NA   0/0        AAC    2 1 0 0     3
# 20   Y     16375336 A   NA   0/0        AAC    2 1 0 0     3
# 21   Y     17176627 A   NA   0/0        AAC    2 1 0 0     3
# 22   Y     17239125 A   NA   0/0        AAC    2 1 0 0     3
# 23   Y     18405840 A   NA   0/0        AAC    2 1 0 0     3
# 24   Y     18670421 A   NA   0/0        AAC    2 1 0 0     3
# 25   Y     18696792 A   NA   0/0        ACA    2 1 0 0     3
# 26   Y     19032539 A   NA   0/0        AAC    2 1 0 0     3
# 27   Y     19064381 A   NA   0/0        AAC    2 1 0 0     3
# 28   Y     21642771 A   NA   0/0        AAC    2 1 0 0     3
# 29   Y     21731086 C   NA   1/1        ACA    2 1 0 0 A   3
# 30   Y     23387307 A   NA   0/0        ACA    2 1 0 0     3
# ⋮    ⋮     ⋮        ⋮   ⋮    ⋮          ⋮      ⋮ ⋮ ⋮ ⋮ ⋮   ⋮
# 5286 Y     18804560 G   NA   0/0        GTG    0 0 2 1     3
# 5287 Y     18980937 G   NA   0/0        GTG    0 0 2 1     3
# 5288 Y     19293495 T   NA   1/1        GGT    0 0 2 1 G   3
# 5289 Y     19337304 G   NA   0/0        GTG    0 0 2 1     3
# 5290 Y     19453211 G   NA   0/0        TGG    0 0 2 1     3
# 5291 Y     22652883 G   NA   0/0        GTG    0 0 2 1     3
# 5292 Y     24396870 G   NA   0/0        GTG    0 0 2 1     3
# 5293 Y      6912862 T   NA   0/0        TTG    0 0 1 2     3
# 5294 Y      7103985 T   NA   0/0        GTT    0 0 1 2     3
# 5295 Y      7250457 T   NA   0/0        GTT    0 0 1 2     3
# 5296 Y      7514271 T   NA   0/0        TTG    0 0 1 2     3
# 5297 Y      8375769 T   NA   0/0        TTG    0 0 1 2     3
# 5298 Y     14288125 T   NA   0/0        TGT    0 0 1 2     3
# 5299 Y     14750657 T   NA   0/0        GTT    0 0 1 2     3
# 5300 Y     14791304 G   NA   1/1        TTG    0 0 1 2 T   3
# 5301 Y     14945827 T   NA   0/0        TTG    0 0 1 2     3
# 5302 Y     15052713 T   NA   0/0        GTT    0 0 1 2     3
# 5303 Y     15660700 T   NA   0/0        GTT    0 0 1 2     3
# 5304 Y     15829944 T   NA   0/0        GTT    0 0 1 2     3
# 5305 Y     16764911 T   NA   0/0        TTG    0 0 1 2     3
# 5306 Y     16786220 T   NA   0/0        TTG    0 0 1 2     3
# 5307 Y     17239127 T   NA   0/0        TTG    0 0 1 2     3
# 5308 Y     18052583 T   NA   0/0        GTT    0 0 1 2     3
# 5309 Y     18208858 T   NA   0/0        TGT    0 0 1 2     3
# 5310 Y     18420455 T   NA   0/0        GTT    0 0 1 2     3
# 5311 Y     19118168 G   NA   1/1        TTG    0 0 1 2 T   3
# 5312 Y     19453209 T   NA   0/0        GTT    0 0 1 2     3
# 5313 Y     21440733 T   NA   0/0        TGT    0 0 1 2     3
# 5314 Y     23455624 T   NA   0/0        TGT    0 0 1 2     3
# 5315 Y     24361136 T   NA   0/0        TGT    0 0 1 2     3
