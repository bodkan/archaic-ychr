# %%
library(phangorn)
# Out:
# Loading required package: ape

# %%
aln <- read.phyDat("../out.tsv.fa", format = "fasta")

# %%
tree <- NJ(dist.ml(aln))

# %%
rooted_tree <- root(tree, outgroup = c("chimp0"), resolve.root = TRUE)

# %%
plot(rooted_tree, use.edge.length=F)
# Out:
# plot without title
