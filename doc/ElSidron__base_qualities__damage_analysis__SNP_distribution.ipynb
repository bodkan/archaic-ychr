# %%
import sys
import os
import glob

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sys.path.append(os.path.expanduser('~') + '/devel/bam-utils')

# %% [markdown]
# <br><br><br><br><br>
# # Distributions of base qualities in El Sidron BAM files

# %%
from bam_plotbqual import bquals_sample, plot_bqual_dist

# %%
for bamfile in glob.glob('../bam/*sidron*.bam'):
    bquals = bquals_sample(bamfile, 10000)
    plot_bqual_dist(bquals, bamfile)

# %% [markdown]
# <br><br><br><br><br>
# # Distributions of read lengths in El Sidron BAM files

# %%
from bam_plotlength import count_read_lengths, plot_length_dist

# %%
for bamfile in glob.glob('../bam/*sidron*.bam'):
    read_lengths = count_read_lengths(bamfile)
    plot_length_dist(read_lengths, bamfile)

# %% [markdown]
# <br><br><br><br><br>
# # Damage patterns

# %% [markdown]
# ![](../figures/subst_from_5_prime_end__sidron_ontarget.bam.png)
# ![](../figures/subst_from_3_prime_end__sidron_ontarget.bam.png)

# %% [markdown]
# ![](../figures/subst_from_5_prime_end__exome_sidron_ontarget.bam.png)
# ![](../figures/subst_from_3_prime_end__exome_sidron_ontarget.bam.png)

# %% [markdown]
# # Distributions of SNPs in El Sidron VCF files

# %%
from vcf_snpdist import count_snps, plot_snp_counts

# %% [markdown]
# ## raw El Sidron VCF

# %%
snp_counts = count_snps('../vcf/merged_all_ontarget.vcf.gz', 'ElSidron', 'Y')

# %%
_ = plot_snp_counts(snp_counts, 'ElSidron')

# %% [markdown]
# ## El Sidron VCF from BAM with decreased qualities of putative damage bases

# %%
snp_counts = count_snps('../vcf/merged_all_ontarget.vcf.gz', 'ElSidronDQ', 'Y')

# %%
_ = plot_snp_counts(snp_counts, 'ElSidronDQ')

# %% [markdown]
# ## El Sidron VCF -- majority call, base quality >= 20, minimal depth 3

# %%
snp_counts = count_snps('../vcf/merged_all_ontarget.vcf.gz', 'ElSidronMaj', 'Y')

# %%
_ = plot_snp_counts(snp_counts, 'ElSidronMaj')

# %% [markdown]
# ## El Sidron exome chromosome 17

# %%
snp_counts = count_snps('../vcf/exome17_sidron_ontarget.vcf.gz', 'ElSidronExome', '17')

# %%
_ = plot_snp_counts(snp_counts, 'ElSidronExome')

# %% [markdown]
# ## Qiaomei's Sidron VCF

# %%
snp_counts = count_snps('../vcf/merged_all_ontarget.vcf.gz', 'Sidron', 'Y')

# %%
_ = plot_snp_counts(snp_counts, 'Qiaomei\'s Sidron VCF')

# %% [markdown]
# ## Modern human HGDP00001 -- samtools & bcftools

# %%
snp_counts = count_snps('../vcf/humans_ontarget.vcf.gz', 'HGDP00001', 'Y')

# %%
_ = plot_snp_counts(snp_counts, 'HGDP00001')
