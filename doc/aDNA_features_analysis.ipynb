# %% [markdown]
# # Analysis of ancient DNA features for on target data

# %%
# make sure dependencies have been generated (they should have been
# if this notebook is run in batch mode by make)
!(cd ../; make init)
# Out:
# make[1]: Entering directory `/mnt/expressions/mp/y'
# make[1]: Nothing to be done for `init'.
# make[1]: Leaving directory `/mnt/expressions/mp/y'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
sys.path.append('../src')
from analyze_damage import *

# %%
# %matplotlib inline

# %%
sns.set_palette(sns.color_palette("husl", 12))

# %%
def plot_damage(bam_file, ylim=30):
    fwd_mismatches, rev_mismatches = analyze_bam(bam_file)
    _ = plot_mismatches(fwd_mismatches, 'damage on forward -- ' + bam_file, ylim)
    _ = plot_mismatches(rev_mismatches, 'damage on reversed -- ' + bam_file, ylim)

# %% [markdown]
# ## El Sidron on target

# %%
bam_file = '../bam/sidron_ontarget.bam'

# %%
plot_damage(bam_file)
# Out:
# Total number of forward reads: 48778
# Total number of reverse reads: 43574

# %%
plot_damage(bam_file, 1)
# Out:
# Total number of forward reads: 48778
# Total number of reverse reads: 43574

# %%
read_lengths = count_read_lengths(bam_file)
_ = plot_length_dist(read_lengths, 'read length -- ' + bam_file)

# %% [markdown]
# ## Denisova 8 (ALL FRAGMENTS) on target

# %%
bam_file = '../bam/den8_ontarget.bam'

# %%
plot_damage(bam_file)
# Out:
# Total number of forward reads: 277
# Total number of reverse reads: 284

# %%
read_lengths = count_read_lengths(bam_file)
_ = plot_length_dist(read_lengths, 'read length -- ' + bam_file)

# %% [markdown]
# ## Denisova 8 (DEAM ONLY) on target

# %%
bam_file = '../bam/deam_den8_ontarget.bam'

# %%
plot_damage(bam_file)
# Out:
# Total number of forward reads: 59
# Total number of reverse reads: 43

# %%
read_lengths = count_read_lengths(bam_file)
_ = plot_length_dist(read_lengths, 'read length -- ' + bam_file)
